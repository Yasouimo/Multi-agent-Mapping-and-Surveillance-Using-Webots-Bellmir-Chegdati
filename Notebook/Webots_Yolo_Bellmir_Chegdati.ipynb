# %% [markdown]
# # E-puck Multi agent surveillance Using Yolov8
#
# **u can find the data i used for training and the results in the link here**
#
# https://drive.google.com/drive/folders/1d154IzF_oMZBFZpEqOun4PcwQIh7QTCs?usp=sharing

# %% [markdown]
# # Importing and Downloading

# %%
#set up google drive to access our data
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/Webots_Maze2.v4i.yolov8.zip" -d "/content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati"
# Out:
# Archive:  /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/Webots_Maze2.v4i.yolov8.zip
#   inflating: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/README.dataset.txt
#   inflating: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/README.roboflow.txt
#   inflating: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/data.yaml
#    creating: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/train/
#    creating: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/train/images/
#  extracting: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/train/images/cardborad_box1_png.rf.b74f7cc2912ddaec2200d72346d98e8e.jpg
#  extracting: /content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/train/images/cardborad_box1_png.rf.b78390230823a5660d5640d64bccec62.jpg
# ...

# %%
#install and import ultralytics
# !pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.0/112.6 GB disk)

# %%
#install supervision
# !pip install supervision
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 10.2 MB/s eta 0:00:00
# ...

# %%
#import a pretrained YOLO model
import os
from ultralytics import YOLO

model = YOLO('yolov8n.pt')

from IPython.display import display, Image
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 119MB/s]

# %% [markdown]
# # Model Training

# %%
# !pip install -U jax jaxlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 49.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 MB 9.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 110.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: ml_dtypes
#     Found existing installation: ml-dtypes 0.4.1
#     Uninstalling ml-dtypes-0.4.1:
#       Successfully uninstalled ml-dtypes-0.4.1
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.5.1
#     Uninstalling jaxlib-0.5.1:
#       Successfully uninstalled jaxlib-0.5.1
#   Attempting uninstall: jax
#     Found existing installation: jax 0.5.2
#     Uninstalling jax-0.5.2:
#       Successfully uninstalled jax-0.5.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ...

# %%
from jax.tree_util import tree_unflatten
# Out:
# /usr/local/lib/python3.11/dist-packages/jaxlib/plugin_support.py:71: RuntimeWarning: JAX plugin jax_cuda12_plugin version 0.5.1 is installed, but it is not compatible with the installed jaxlib version 0.6.0, so it will not be used.
#   warnings.warn(

# %%
ROOT_DIR = "/content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati" # Define ROOT_DIR
results = model.train(data=os.path.join(ROOT_DIR, "data.yaml"), epochs=100)  #train the model.
results = model.val()  #evaluate model performance on the validation set
# Out:
# Ultralytics 8.3.111 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
import shutil
source = '/content/runs'
destination = '/content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/runs'

# Use shutil to copy the directory with the dirs_exist_ok parameter
shutil.copytree(source, destination, dirs_exist_ok=True)
# Out:
# '/content/drive/MyDrive/Webots_Model_Training_Bellmir_Chegdati/runs'
